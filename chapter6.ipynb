# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/home/akshat/Desktop/Python_data_analysis/dummy_data/dummy.csv")

# %%
df
# Out:
#    ID           Name  Age   Department  Salary
# 0   1       John Doe   28  Engineering   75000
# 1   2     Jane Smith   34    Marketing   68000
# 2   3    Emily Davis   25           HR   62000
# 3   4  Michael Brown   40      Finance   85000
# 4   5    Anna Wilson   29  Engineering   77000
# 5   6  David Johnson   38        Sales   72000
# 6   7     Lisa White   30           HR   60000
# 7   8    James Green   45      Finance   92000
# 8   9     Mary Adams   27        Sales   69000
# 9  10    Robert King   33    Marketing   71000

# %%
df2 = pd.read_table("/home/akshat/Desktop/Python_data_analysis/dummy_data/dummy.csv",sep = ",")

# %%
df2
# Out:
#    ID           Name  Age   Department  Salary
# 0   1       John Doe   28  Engineering   75000
# 1   2     Jane Smith   34    Marketing   68000
# 2   3    Emily Davis   25           HR   62000
# 3   4  Michael Brown   40      Finance   85000
# 4   5    Anna Wilson   29  Engineering   77000
# 5   6  David Johnson   38        Sales   72000
# 6   7     Lisa White   30           HR   60000
# 7   8    James Green   45      Finance   92000
# 8   9     Mary Adams   27        Sales   69000
# 9  10    Robert King   33    Marketing   71000

# %%
df_wh = pd.read_csv("/home/akshat/Desktop/Python_data_analysis/dummy_data/dummy_without_header.csv",header=None)

# %%
df_wh2 = pd.read_csv("/home/akshat/Desktop/Python_data_analysis/dummy_data/dummy_without_header.csv")

# %%
df_wh2
# Out:
#     1       John Doe  28  Engineering  75000
# 0   2     Jane Smith  34    Marketing  68000
# 1   3    Emily Davis  25           HR  62000
# 2   4  Michael Brown  40      Finance  85000
# 3   5    Anna Wilson  29  Engineering  77000
# 4   6  David Johnson  38        Sales  72000
# 5   7     Lisa White  30           HR  60000
# 6   8    James Green  45      Finance  92000
# 7   9     Mary Adams  27        Sales  69000
# 8  10    Robert King  33    Marketing  71000

# %%
df_wh_wname = pd.read_csv("/home/akshat/Desktop/Python_data_analysis/dummy_data/dummy_without_header.csv",names = ['S.no','Names','age','Field','Salary'])

# %%
df_wh_wname
# Out:
#    S.no          Names  age        Field  Salary
# 0     1       John Doe   28  Engineering   75000
# 1     2     Jane Smith   34    Marketing   68000
# 2     3    Emily Davis   25           HR   62000
# 3     4  Michael Brown   40      Finance   85000
# 4     5    Anna Wilson   29  Engineering   77000
# 5     6  David Johnson   38        Sales   72000
# 6     7     Lisa White   30           HR   60000
# 7     8    James Green   45      Finance   92000
# 8     9     Mary Adams   27        Sales   69000
# 9    10    Robert King   33    Marketing   71000

# %%
df_wh_wname = pd.read_csv("/home/akshat/Desktop/Python_data_analysis/dummy_data/dummy_without_header.csv",names = ['S.no','Names','age','Field','Salary'],)

# %%
df_wh_wname
# Out:
#    S.no          Names  age        Field  Salary
# 0     1       John Doe   28  Engineering   75000
# 1     2     Jane Smith   34    Marketing   68000
# 2     3    Emily Davis   25           HR   62000
# 3     4  Michael Brown   40      Finance   85000
# 4     5    Anna Wilson   29  Engineering   77000
# 5     6  David Johnson   38        Sales   72000
# 6     7     Lisa White   30           HR   60000
# 7     8    James Green   45      Finance   92000
# 8     9     Mary Adams   27        Sales   69000
# 9    10    Robert King   33    Marketing   71000

# %%
df_wh_wname = pd.read_csv("/home/akshat/Desktop/Python_data_analysis/dummy_data/dummy_without_header.csv",names = ['ID','Names','age','Field','Salary'],index_col= "ID")

# %%
df_wh_wname
# Out:
#             Names  age        Field  Salary
# ID
# 1        John Doe   28  Engineering   75000
# 2      Jane Smith   34    Marketing   68000
# 3     Emily Davis   25           HR   62000
# 4   Michael Brown   40      Finance   85000
# 5     Anna Wilson   29  Engineering   77000
# 6   David Johnson   38        Sales   72000
# 7      Lisa White   30           HR   60000
# 8     James Green   45      Finance   92000
# 9      Mary Adams   27        Sales   69000
# 10    Robert King   33    Marketing   71000

# %%
list(open("/home/akshat/Desktop/Python_data_analysis/dummy_data/sample_data_space.txt"))
# Out:
# ['ID Name Age Department Salary\n',
#  '1 John_Doe 28 Engineering 75000\n',
#  '2 Jane_Smith 34 Marketing 68000\n',
#  '3 Emily_Davis 25 HR 62000\n',
#  '4 Michael_Brown 40 Finance 85000\n',
#  '5 Anna_Wilson 29 Engineering 77000\n',
#  '6 David_Johnson 38 Sales 72000\n',
#  '7 Lisa_White 30 HR 60000\n',
#  '8 James_Green 45 Finance 92000\n',
#  '9 Mary_Adams 27 Sales 69000\n',
#  '10 Robert_King 33 Marketing 71000\n']

# %%
cat /home/akshat/Desktop/Python_data_analysis/dummy_data/sample_data_space.txt
# Out:
# ID Name Age Department Salary
# 1 John_Doe 28 Engineering 75000
# 2 Jane_Smith 34 Marketing 68000
# 3 Emily_Davis 25 HR 62000
# 4 Michael_Brown 40 Finance 85000
# 5 Anna_Wilson 29 Engineering 77000
# 6 David_Johnson 38 Sales 72000
# 7 Lisa_White 30 HR 60000
# 8 James_Green 45 Finance 92000
# 9 Mary_Adams 27 Sales 69000
# 10 Robert_King 33 Marketing 71000

# %%
df_sp = pd.read_table("/home/akshat/Desktop/Python_data_analysis/dummy_data/sample_data_space.txt",delimiter= "\s+",index_col="ID")

# %%
df_sp
# Out:
#              Name  Age   Department  Salary
# ID
# 1        John_Doe   28  Engineering   75000
# 2      Jane_Smith   34    Marketing   68000
# 3     Emily_Davis   25           HR   62000
# 4   Michael_Brown   40      Finance   85000
# 5     Anna_Wilson   29  Engineering   77000
# 6   David_Johnson   38        Sales   72000
# 7      Lisa_White   30           HR   60000
# 8     James_Green   45      Finance   92000
# 9      Mary_Adams   27        Sales   69000
# 10    Robert_King   33    Marketing   71000

# %%
df_sp_clean = pd.read_table("/home/akshat/Desktop/Python_data_analysis/dummy_data/sample_data_space_random.txt",delimiter= "\s+",skiprows= [3,7,10])

# %%
df_sp_clean
# Out:
#    ID           Name  Age   Department  Salary
# 0   1       John_Doe   28  Engineering   75000
# 1   2     Jane_Smith   34    Marketing   68000
# 2   3    Emily_Davis   25           HR   62000
# 3   4  Michael_Brown   40      Finance   85000
# 4   5    Anna_Wilson   29  Engineering   77000
# 5   6  David_Johnson   38        Sales   72000
# 6   7     Lisa_White   30           HR   60000
# 7   8    James_Green   45      Finance   92000
# 8   9     Mary_Adams   27        Sales   69000
# 9  10    Robert_King   33    Marketing   71000

# %%
df_missing = pd.read_csv("/home/akshat/Desktop/Python_data_analysis/dummy_data/missing_values.csv",na_values=[""," "])

# %%
df_missing
# Out:
#       Name   Age   Gender          City   Salary
# 0    Alice  30.0   Female      New York  70000.0
# 1      Bob   NaN     Male   Los Angeles  55000.0
# 2  Charlie  25.0      NaN       Chicago      NaN
# 3    David  28.0     Male           NaN  60000.0
# 4      Eve  35.0   Female         Miami  80000.0
# 5    Frank   NaN     Male       Seattle  65000.0
# 6    Grace  29.0   Female           NaN      NaN

# %%
pd.isnull(df_missing)
# Out:
#     Name    Age   Gender   City   Salary
# 0  False  False    False  False    False
# 1  False   True    False  False    False
# 2  False  False     True  False     True
# 3  False  False    False   True    False
# 4  False  False    False  False    False
# 5  False   True    False  False    False
# 6  False  False    False   True     True

# %%
# Different Sentinels can be assigned for each row in the dataframe

sentinels = {'Name' : ['Grace','Frank'],'City' : ['Chicago']}
df_missing2 = pd.read_csv("/home/akshat/Desktop/Python_data_analysis/dummy_data/missing_values.csv",na_values=sentinels)
df_missing2
# Out:
#       Name  Age   Gender          City  Salary
# 0    Alice   30   Female      New York   70000
# 1      Bob          Male   Los Angeles   55000
# 2  Charlie   25                Chicago
# 3    David   28     Male                 60000
# 4      Eve   35   Female         Miami   80000
# 5      NaN          Male       Seattle   65000
# 6      NaN   29   Female

# %%
pd.options.display.max_rows = 10

# %%
survey_data = pd.read_csv("/home/akshat/Desktop/Python_data_analysis/dummy_data/annual-enterprise-survey-2023-financial-year-provisional.csv")

# %%
survey_data
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2023                     Level 1                99999
# 1      2023                     Level 1                99999
# 2      2023                     Level 1                99999
# 3      2023                     Level 1                99999
# 4      2023                     Level 1                99999
# ...     ...                         ...                  ...
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
survey_data_test_chunk = pd.read_csv("/home/akshat/Desktop/Python_data_analysis/dummy_data/annual-enterprise-survey-2023-financial-year-provisional.csv",chunksize= 500)

# %%
survey_data_test_chunk

# %%
df
# Out:
#    ID           Name  Age   Department  Salary
# 0   1       John Doe   28  Engineering   75000
# 1   2     Jane Smith   34    Marketing   68000
# 2   3    Emily Davis   25           HR   62000
# 3   4  Michael Brown   40      Finance   85000
# 4   5    Anna Wilson   29  Engineering   77000
# 5   6  David Johnson   38        Sales   72000
# 6   7     Lisa White   30           HR   60000
# 7   8    James Green   45      Finance   92000
# 8   9     Mary Adams   27        Sales   69000
# 9  10    Robert King   33    Marketing   71000

# %%
df.to_csv("/home/akshat/Desktop/Python_data_analysis/dummy_data/output.csv")

# %%
import sys
df.to_csv(sys.stdout ,sep = ",")
# Out:
# ,ID,Name,Age,Department,Salary
# 0,1,John Doe,28,Engineering,75000
# 1,2,Jane Smith,34,Marketing,68000
# 2,3,Emily Davis,25,HR,62000
# 3,4,Michael Brown,40,Finance,85000
# 4,5,Anna Wilson,29,Engineering,77000
# 5,6,David Johnson,38,Sales,72000
# 6,7,Lisa White,30,HR,60000
# 7,8,James Green,45,Finance,92000
# 8,9,Mary Adams,27,Sales,69000
# 9,10,Robert King,33,Marketing,71000

# %%
import csv

# %%
f = open('/home/akshat/Desktop/Python_data_analysis/dummy_data/db_quotes.csv')

# %%
reader = csv.reader(f)

# %%
reader

# %%
for line in reader:
    print(line)
# Out:
# ['Name', 'Age', 'City']
# ['John Doe', '28', 'New York']
# ['Jane Smith', '34', 'Los Angeles']
# ['Sam Brown', '22', 'Chicago']
# ['Emily Davis', '30', 'Houston']

# %%
with open('/home/akshat/Desktop/Python_data_analysis/dummy_data/db_quotes.csv') as f:
    lines = list(csv.reader(f))

# %%
lines
# Out:
# [['Name', 'Age', 'City'],
#  ['John Doe', '28', 'New York'],
#  ['Jane Smith', '34', 'Los Angeles'],
#  ['Sam Brown', '22', 'Chicago'],
#  ['Emily Davis', '30', 'Houston']]

# %%
header,values = lines[0] , lines[1:]

# %%
header
# Out:
# ['Name', 'Age', 'City']

# %%
values
# Out:
# [['John Doe', '28', 'New York'],
#  ['Jane Smith', '34', 'Los Angeles'],
#  ['Sam Brown', '22', 'Chicago'],
#  ['Emily Davis', '30', 'Houston']]

# %%
list(zip(header,values))
# Out:
# [('Name', ['John Doe', '28', 'New York']),
#  ('Age', ['Jane Smith', '34', 'Los Angeles']),
#  ('City', ['Sam Brown', '22', 'Chicago'])]

# %%
list(zip(header,*values))
# Out:
# [('Name', 'John Doe', 'Jane Smith', 'Sam Brown', 'Emily Davis'),
#  ('Age', '28', '34', '22', '30'),
#  ('City', 'New York', 'Los Angeles', 'Chicago', 'Houston')]

# %%
list(zip(header,zip(*values)))
# Out:
# [('Name', ('John Doe', 'Jane Smith', 'Sam Brown', 'Emily Davis')),
#  ('Age', ('28', '34', '22', '30')),
#  ('City', ('New York', 'Los Angeles', 'Chicago', 'Houston'))]

# %%
list(zip(*values))
# Out:
# [('John Doe', 'Jane Smith', 'Sam Brown', 'Emily Davis'),
#  ('28', '34', '22', '30'),
#  ('New York', 'Los Angeles', 'Chicago', 'Houston')]

# %% [markdown]
# ### h : v means that h is the key and v is the value then we are iterating over zip(header,zip*values) assigning their values to h and v

# %%
{h:v for h,v in zip(header,zip(*values))}
# Out:
# {'Name': ('John Doe', 'Jane Smith', 'Sam Brown', 'Emily Davis'),
#  'Age': ('28', '34', '22', '30'),
#  'City': ('New York', 'Los Angeles', 'Chicago', 'Houston')}

# %%
print(csv.list_dialects())
# Out:
# ['excel', 'excel-tab', 'unix']
